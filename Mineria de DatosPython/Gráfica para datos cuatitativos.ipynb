# %%
import matplotlib.pyplot as plt
frecuencia = [6,10,7,12,7]
nombres = ["David","Johnson","Jones","Smith","Williams"]
plt.pie(frecuencia, labels=nombres, autopct="%0.1f %%")
plt.axis("equal")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'frecuencia': [6, 10, 7, 12, 7]})
df.index = ['Davis', 'Johnson', 'Jones', 'Smith', 'Williams']
df = df.sort_values(by='frecuencia',ascending=False)
frecuencia_relativa = df["frecuencia"].cumsum()
total_defectos = df["frecuencia"].sum()
df["cumpercentage"] = frecuencia_relativa/total_defectos*100


fig, ax = plt.subplots()
ax.bar(df.index, df["frecuencia"], color="C0")
ax2 = ax.twinx()
ax2.plot(df.index, df["cumpercentage"], color="C1", marker="o", ms=5)


plt.show()

# %%
import matplotlib.pyplot as plt
 
## Declaramos valores para el eje x
eje_x = ['Davis', 'Johnson', 'Jones', 'Smith','William']
 
## Declaramos valores para el eje y
eje_y = [6,10,7,12,7]
 
## Creamos Gráfica
plt.bar(eje_x, eje_y)
 
## Legenda en el eje y
plt.ylabel('Frecuencia')
 
## Legenda en el eje x
plt.xlabel('DAtos')
 
## Título de Gráfica
plt.title('Datos Cualitativos')
 
## Mostramos Gráfica
plt.show()
